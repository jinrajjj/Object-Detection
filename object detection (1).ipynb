# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv

# %%
# !pip install cvlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from cvlib.object_detection import draw_bbox
detect_image = cv2.imread('drive/My Drive/img2.jpeg')

# %%
###for sliding window
stepSize = 100
(w_width, w_height) = (100, 100) # window size
for x in range(0, detect_image.shape[2] - w_width , stepSize):
   for y in range(0, detect_image.shape[2] - w_height, stepSize):
      window = im[x:x + w_width, y:y + w_height, :]

# %%
print(detect_image)
# Out:
# [[[ 59  82  84]
#   [ 42  65  67]
#   [ 28  49  51]
#   ...
#   [  0   0   7]
#   [  0   0   1]
#   [  0   0   0]]
#
#  [[ 58  81  83]
#   [ 42  65  67]
#   [ 29  50  52]
#   ...
#   [  0   0   8]
#   [  0   0   1]
#   [  0   0   0]]
#
#  [[ 54  77  79]
#   [ 41  64  66]
#   [ 32  53  55]
#   ...
#   [  0   0   6]
#   [  0   0   1]
#   [  0   0   0]]
#
#  ...
#
#  [[213 215 215]
#   [213 215 215]
#   [213 215 215]
#   ...
#   [217 219 219]
#   [217 217 217]
#   [217 217 217]]
#
#  [[253 255 255]
#   [253 255 255]
#   [253 255 255]
#   ...
#   [253 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[253 255 255]
#   [253 255 255]
#   [253 255 255]
#   ...
#   [253 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
bbox, label, conf = cv.detect_common_objects(detect_image)
output_image = draw_bbox(detect_image, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
plt.imshow(output_image)
